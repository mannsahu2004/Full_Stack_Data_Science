# %% [markdown]
# Complement

# %%
~12
# Out:
# -13

# %%
~46
# Out:
# -47

# %% [markdown]
# AND

# %%
12 & 13
# Out:
# 12

# %% [markdown]
# OR

# %%
12 | 13
# Out:
# 13

# %% [markdown]
# XOR

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
bin(7)
# Out:
# '0b111'

# %% [markdown]
# Left shift and Right shift

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10>>1
# Out:
# 5
