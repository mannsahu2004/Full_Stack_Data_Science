# %% [markdown]
#  List Datastructures

# %%
l = []
l
# Out:
# []

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l.append(10,20)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-1] = -50

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
 l1 = l.copy()

# %%
l1
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
print(l)
print(l1)
# Out:
# [100, 20, 30, 40, 50, -50]
# [100, 20, 30, 40, 50, -50]

# %%
l == l1
# Out:
# True

# %%
id(l) == id(l1)
# Out:
# False

# %%
id(l) != id(l1)
# Out:
# True

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l.count(20)
# Out:
# 1

# %%
len(l1)
# Out:
# 6

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l2 = []

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(2.5)

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 2.5]

# %%
print(l)
print(l2)
# Out:
# [100, 20, 30, 40, 50, -50]
# [9, 'nit', True, (1+2j), 2.5]

# %%
l.index(100)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l2[1]
# Out:
# 'nit'

# %%
l2[1][0]
# Out:
# 'n'

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l[:]
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l[3:]
# Out:
# [40, 50, -50]

# %%
l[:10]
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l[0:8:3]
# Out:
# [100, 40]

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 2.5]

# %%
l2[1:6:2]
# Out:
# ['nit', (1+2j)]

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50]

# %%
l.insert(15,2)

# %%
l
# Out:
# [100, 20, 30, 40, 50, -50, 2]

# %%
l.insert(2,15) #2nd index position & 15 is called value

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50, -50, 2]

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50, -50]

# %%
l.pop()
# Out:
# -50

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50]

# %%
l2
# Out:
# [9, 'nit', True, (1+2j), 2.5]

# %%
l2.pop(3)
# Out:
# (1+2j)

# %%
l2
# Out:
# [9, 'nit', True, 2.5]

# %%
l2.remove('nit')

# %%
l2
# Out:
# [9, True, 2.5]

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50]

# %%
100 in l
# Out:
# True

# %%
1000 in l
# Out:
# False

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50]

# %%
for i in l:
    print(i)
# Out:
# 100
# 20
# 15
# 15
# 30
# 40
# 50

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 100)
# (1, 20)
# (2, 15)
# (3, 15)
# (4, 30)
# (5, 40)
# (6, 50)

# %%
print(l)
print(l2)
# Out:
# [100, 20, 15, 15, 30, 40, 50]
# [9, True, 2.5]

# %%
l2.extend(l)

# %%
l2
# Out:
# [9, True, 2.5, 100, 20, 15, 15, 30, 40, 50]

# %%
l
# Out:
# [100, 20, 15, 15, 30, 40, 50]

# %%
l.sort()

# %%
l
# Out:
# [15, 15, 20, 30, 40, 50, 100]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [100, 50, 40, 30, 20, 15, 15]

# %%
l2
# Out:
# [9, True, 2.5, 100, 20, 15, 15, 30, 40, 50]

# %%
l3 = [1, 2.3, 'nit', True]
l3
# Out:
# [1, 2.3, 'nit', True]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l4 = ['a','g','n','m']
l4
# Out:
# ['a', 'g', 'n', 'm']

# %%
l4.sort()

# %%
l4
# Out:
# ['a', 'g', 'm', 'n']

# %% [markdown]
# #ALL & ANY

# %%
l
# Out:
# [100, 50, 40, 30, 20, 15, 15]

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)

# %%
l
# Out:
# [100, 50, 40, 30, 20, 15, 15, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True

# %% [markdown]
# Tuple

# %%
t = ()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10,20,30)
t1
# Out:
# (10, 20, 30)

# %%
t1.append(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 t1.append(20)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
sbi = ('alex',123456789,'cizp567',4567)
sbi
# Out:
# ('alex', 123456789, 'cizp567', 4567)

# %%
sbi[1]
# Out:
# 123456789

# %%
sbi[1] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 sbi[1] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(20)
# Out:
# 1

# %%
t1
# Out:
# (10, 20, 30)

# %%
for i in t1:
    print(i)
# Out:
# 10
# 20
# 30

# %%
for i in enumerate(t1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t2 = t1*3
t2
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t2[2:6]
# Out:
# (30, 10, 20, 30)

# %%
t2.remove(20
