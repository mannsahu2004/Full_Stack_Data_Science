# %%
a = 4
b = 4

# %%
a<8 and b<5 # refer to the truth table
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a<8 or b<2
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x # you can reverse the operation
# Out:
# True

# %%
x
# Out:
# False

# %%
not x
# Out:
# True
