# %%
9
# Out:
# 9

# %%
9+9
# Out:
# 18

# %%
9-9
# Out:
# 0

# %%
10*2
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10//5
# Out:
# 2

# %%
3*2
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
9
# Out:
# 9

# %%
int(_) + 3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int(_) + 3
#
# ValueError: invalid literal for int() with base 10: '{"dataframes": [], "user": "manns"}'

# %%
3+6*4-2-1
# Out:
# 24

# %%
3+6*4-(2-1)
# Out:
# 26

# %%
math.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 math.pi
#
# NameError: name 'math' is not defined

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(9.4)
# Out:
# 10

# %%
math.floor(9.4)
# Out:
# 9

# %%
welcome to nit
# Out:
#   Cell In[24], line 1
#     welcome to nit
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to nit'
# Out:
# 'welcome to nit'

# %%
"welcome to nit"
# Out:
# 'welcome to nit'

# %%
'''welcome to nit'''
# Out:
# 'welcome to nit'

# %%
'welcome to nit'
# Out:
# 'welcome to nit'

# %%
'welcome to 
nit'
# Out:
#   Cell In[29], line 1
#     'welcome to
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to 
nit"
# Out:
#   Cell In[30], line 1
#     "welcome to
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s = 'welcome to nit'
s
# Out:
# 'welcome to nit'

# %%
s[0]
# Out:
# 'w'

# %%
s[1]
# Out:
# 'e'

# %%
s[8]
# Out:
# 't'
