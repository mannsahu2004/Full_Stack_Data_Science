# %%
if True:
    print('Data science')
# Out:
# Data science

# %%
if True:
    print('Data science')
print('how are you')
# Out:
# Data science
# how are you

# %%
if False:
    print('bye')

# %%
if False:
    print('Data Science')

print('bye')
# Out:
# bye

# %%
if False:
    print('Data science')

else:
    print('bye')
# Out:
# bye

# %% [markdown]
# Write python code to check whether number is even or not

# %%
x = 4

r = x%2

if r==0:
    print('Even number')
# Out:
# Even number

# %%
x = 5

r = x%2

if r == 0:
    print('Even number')

else:
    print('Odd number')
# Out:
# Odd number

# %%
x = 6
r = x%2

if r == 0:
    print("Even number")

print("Odd number")
# Out:
# Even number
# Odd number

# %%
x = 7
r = x%2

if r == 0:
    print("Even number")

else:print("Odd number")
# Out:
# Odd number

# %%
x = 10
r = x%2

if r == 0:
    print('Even number')

if r != 0:
    print('Odd number')
# Out:
# Even number

# %% [markdown]
# Nested if

# %%
x = 6 
r = x%2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')

else:
    print('odd number')
# Out:
# Even number
# greater number

# %%
x = 2
r = x%2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')
    else:
        print('smaller number')

else:
    print('odd number')
# Out:
# Even number
# smaller number

# %% [markdown]
# if  - elif - else

# %%
x = 11

if x == 1:
    print('one')

elif x == 2:
    print('two')

elif x == 3:
    print('three')

elif x == 4:
    print('four')

else:
    print('Number not found')
# Out:
# Number not found

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")

elif num < 0:
    print("Negative")

else :
    print('zero')
# Out:
# Enter a number:  0
# zero

# %% [markdown]
# If else Conditional Statement

# %%
age = 10
if age<=12:
    print("Travel for free.")
else:
    print("Pay for ticket.")
# Out:
# Travel for free.

# %% [markdown]
# Short Hand if-else

# %%
marks = 45
res = "Pass" if marks >=40 else "Fail" #Ternary Operator
print(f"Result: {res}")
# Out:
# Result: Pass

# %% [markdown]
# elif Statement

# %%
age = 25

if age <= 12:
    print("child")
elif age <= 19:
    print("Teenager")
elif age <= 35:
    print("Young adult")
else:
    print("Adult")
# Out:
# Young adult

# %% [markdown]
# Nested if..else Conditional Statement

# %%
age = 70
is_member = True

if age <= 60:
    if is_member:
        print("30% senior discount.")
    else:
        print("20% senior discount.")

else:
    print("Not eligiblle for a senior discount.")
# Out:
# Not eligiblle for a senior discount.

# %% [markdown]
# Ternary Conditional Statement

# %%
# Assign a value based on a condition
age = 18
s = "Adult" if age >=18 else "Minor"
print(s)
# Out:
# Adult

# %% [markdown]
# Match-Case Statement

# %%
number = 2

match number:
    case 1:
        print('one')
    case 2 | 3:
        print('Two or three')
    case _:
        print('Other number')
# Out:
# Two or three

# %% [markdown]
# There are two friends, John and Smith, and the parameters j_angry and s_angry to indicate if each is angry. You are in trouble if both of them are angry or no one of them is angry.
#
# Now, complete the function which returns true if you are in trouble, else return false

# %%
def friends_in_trouble(j_angry, s_angry):
    return(j_angry and s_angry) or (not j_angry and not s_angry)

# %%
print(friends_in_trouble(True, True))
print(friends_in_trouble(True, False))
print(friends_in_trouble(False, True))
print(friends_in_trouble(False, False))
# Out:
# True
# False
# False
# True

# %% [markdown]
# Given a positive integer x. Your task is to check, if it is even or odd (Any number that gives zero as remainder when divided by 2 is an even number).
# Note: Return "Even" if the number is even; otherwise, return "Odd".

# %%
x = 4

if x%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
def CheckEvenOdd(x):
    if x%2 == 0:
        return "Even"
    else:
        return "Odd"

# %%
x = int(input("Enetr a number"))
print(CheckEvenOdd(x))
# Out:
# Enetr a number 2
# Even

# %% [markdown]
# You have to take an interger input a, and then use the if statement to print "Big" (without quotes) if the given number is greater than 100, and use the else statement to print "Small" (without quotes) when the number is smaller than or equal to 100.

# %%
def CheckNumber(x):
    if x>=100:
        return "Big"
    else:
        return "Small"

# %%
x=int(input("Enter a number: "))
print(CheckNumber(x))
# Out:
# Enter a number:  2
# Small

# %%
a = int(input())

if a > 100:
    print("Big")
else:
    print("Small")
# Out:
#  10
# Small

# %% [markdown]
# Given a positive integer n, determine whether it is odd or even. Return true if the number is even and false if the number is odd.
#
# Examples:
#
# Input: n = 15
# Output: false
# Explanation: The number is not divisible by 2, Odd number.
# Input: n = 44
# Output: true
# Explanation: The number is divisible by 2, Even number.
# Constraints:
# 1 ≤ n ≤ 104

# %%
def isEven(n):
    if n%2 == 0:
        return True
    else:
        return False

# %%
n = int(input("Enter a number: "))
print(isEven(n))

# %% [markdown]
# Given three numbers a, b, and c. You need to find which is the greatest of them all.
#
# Examples:
#
# Input: a = 1, b = 2, c = 3
# Output: 3
# Explanation: Clearly, c = 3 is the greatest of (1, 2, 3)
# Input: a = 2, b = 2, c = 5
# Output: 5
# Explanation: Out of (2, 2, 5) 5 is the greatest.
# Constraints:
# 1 <= a, b, c <= 103

# %%
a = int(input())
b = int(input())
c = int(input())

if a >= b and a >= c:
    print(a)
elif b >= a and b >= c:
    print(b)
else:
    print(c)
# Out:
#  2
#  3
#  4
# 4

# %% [markdown]
# Given two numbers a and b. You need to perform basic mathematical operations on them. You will be provided an integer named as operator.
#
# If the operator equals to 1 add a and b, then print the result.
# If the operator equals to 2 subtract b from a, then print the result.
# If the operator equals to 3 multiply a and b, then print the result.
# If the operator equals to any other number, print "Invalid Input"(without quotes).
# Note: Do not add a new line at the end.
#
# Examples:
#
# Input: a = 1, b = 2, operator = 3
# Output: 2
# Explanation: 1 * 2 = 2
# Input: a = 2, b = 2, operator = 2
# Output: 0
# Explanation: 2 - 2 = 0

# %%
class Solution:
    def calculate(self, a: int, b: int, operator: int) -> None:
        if operator == 1:
            print(a+b, end="")
        elif operator == 2:
            print(a-b, end="")
        elif operator == 3:
            print(a*b)
        else:
            print("Invalid Input")

# %%
a = int(input(a))
b = int(input(b))
c = int(input(c))
# Out:
# 2 2

# %% [markdown]
# Given two integers n and m (m != 0). The problem is to find the number closest to n and divisible by m. If there is more than one such number, then output the one having the maximum absolute value.
#
# Examples :
#
# Input: n = 13, m = 4
# Output: 12
# Explanation: 12 is the Closest Number to 13 which is divisible by 4.
# Input: n = -15, m = 6
# Output: -18
# Explanation: Both -12 and -18 are closest to -15 and divisible by 6, but -18 has the maximum absolute value. So, output is -18.
# Constraints:
# -105 ≤ n, m ≤ 105

# %%
class solution:
    def closesNumber(self, n, m):
        q = n//m
        num1 = q*m
        num2 = (q+1)*m

        if abs(n - num1) < abs(n - num2):
            return num1
        elif abs(n - num1) > abs(n - num2):
            return num2
        else:
            return num1 if abs(num1) > abs(num2) else num2

# %%
obj = solution()

print(obj.closesNumber(13, 4))
print(obj.closesNumber(-15, 6))
# Out:
# 12
# -18

# %%
n = -15
m = 6

q = n // m
print("q =", q)

num1 = q * m
num2 = (q + 1) * m
print("num1 =", num1)
print("num2 =", num2)

print("distance from num1 =", abs(n - num1))
print("distance from num2 =", abs(n - num2))
# Out:
# q = -3
# num1 = -18
# num2 = -12
# distance from num1 = 3
# distance from num2 = 3
