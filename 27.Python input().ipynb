# %%
# Q 21.How do you prevent a user from entering an empty string?
while True:
    name = input("Enter your name: ").strip()

    if name == "":
        print("Input cannot be empty.Please try again.")
    else:
        break
        
print("Hello", name)
# Out:
# Enter your name:
# Input cannot be empty.Please try again.
# Enter your name:  mann
# Hello mann

# %%
#without strip it will not work 
while True:
    name = input("Enter your name: ")

    if name == "":
        print("Input cannot be empty.Please try again.")
    else:
        break

print("Hello", name)
# Out:
# Enter your name:
# Hello

# %%
name = input("Enter your name:").strip()

if name == "":
    print("You entered nothing.")
else:
    print("Hello",name)
# Out:
# Enter your name:
# You entered nothing.

# %%
user_input = input("Enter your name: ")

if not user_input:
    print("input cannot be empty.")
else:
    print(f"You entered: {user_input}")
# Out:
# Enter your name:  mann
# You entered: mann

# %%
# Q 22. Write a program to check if an entered number is a perfect square.
import math
num = int(input("Enter a number: "))
if math.isqrt(num)*2 == num:
    print("Perfect square.")
else:
    print("Not a perfect square.")
# Out:
# Enter a number:  4
# Perfect square.

# %%
# Q 23.Write a program that asks the user for a year and determines if it's a leap year
year = int(input("Enter a year: "))
if (year%4 == 0 and year%100 != 0) or (year%400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  2024
# Leap year

# %%
# Q 24.How can you remove leading and trailing spaces from a string input?
user_input = input("Enter someting: ").strip()
# Out:
# Enter someting:  mannshuhiudwg  kdjsoiy

# %%
# Q 25. How do you handle incorrect inputs when you expect an integer using`input()`?
try:
    num = int(input("Enter a number. "))
    print("You entered: ",num)
except ValueError:
    print("Invalid input! Please enter a valid integer.")
# Out:
# Enter a number.  mann
# Invalid input! Please enter a valid integer.

# %%
# Q 26. Write a program that accepts a string and counts the occurrence of a particular character.
text = input("Enter a text: ")
char = input("Enter character to count: ")
print(f"Occurence of {char}: {text.count(char)}")
# Out:
# Enter a text:  mann
# Enter character to count:  a
# Occurence of a: 1

# %%
# Q 27.How would you convert user input to lowercase using `input()`?
text = input("Enter your text: ").lower()
print(text)
# Out:
# Enter your text:  MANN
# mann

# %%
#Q 28.Write a program that accepts a number and prints whether it is a multiple of 10
num = int(input("Enter a number: "))
if num%10 == 0:
    print("Mulltiple of 10.")
else:
    print("Not a multiple of 10.")
# Out:
# Enter a number:  20
# Mulltiple of 10.

# %%
#Q 29.How would you check if a string contains only alphabets using `input()`?
user_input = input("Enter a string: ")
if user_input.isalpha():
    print("Only alphabets")
else:
    print("Contains non-alphabet charcters.")
# Out:
# Enter a string:  1
# Contains non-alphabet charcters.

# %%
#Q 30.Write a program to count the number of words in a sentence entered by the user.
sentence = input("Enter a sentence: ")
# Out:
# Enter a sentence:  mann sahu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 #Q 30.Write a program to count the number of words in a sentence entered by the user.
#       2 sentence = input("Enter a sentence: ")
# ----> 3 sentence.sum()
#
# AttributeError: 'str' object has no attribute 'sum'
