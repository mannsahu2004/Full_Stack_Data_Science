# %%
'Naresh IT'
# Out:
# 'Naresh IT'

# %%
print('Max it')
# Out:
# Max it

# %%
"max it technology"
# Out:
# 'max it technology'

# %%
s1 = 'max it technology'
s1
# Out:
# 'max it technology'

# %%
a = 2
b = 2
a + b
# Out:
# 4

# %%
c = a + b

# %%
c
# Out:
# 4

# %%
a = 3
b = 'hi'
type(b)
# Out:
# str

# %%
print('max it\'s"Technology"')
# Out:
# max it's"Technology"

# %%
print("max it', 'Technology")
# Out:
# max it', 'Technology

# %%
#print the nit 2 items
'nit' + 'nit'
# Out:
# 'nitnit'

# %%
'nit ' ' nit'
# Out:
# 'nit  nit'

# %%
5 + 'nit'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 5 + 'nit'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
5 * 'nit'
# Out:
# 'nitnitnitnitnit'

# %%
5*' nit'
# Out:
# ' nit nit nit nit nit'

# %%
print(r'D:\NIT notes')
# Out:
# D:\NIT notes

# %%
name = 'mit'

# %%
name
# Out:
# 'mit'

# %%
name + 'technology'
# Out:
# 'mittechnology'

# %%
name 'technology'
# Out:
#   Cell In[27], line 1
#     name 'technology'
#          ^
# SyntaxError: invalid syntax

# %%
'a' 'b'
# Out:
# 'ab'

# %%
len(name)
# Out:
# 3

# %%
name1 = 'fine'
name1
# Out:
# 'fine'

# %%
name1[0:1] ='d'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 name1[0:1] ='d'
#
# TypeError: 'str' object does not support item assignment

# %%
name1[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 name1[0] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
name1
# Out:
# 'fine'

# %%
name1[1:]
# Out:
# 'ine'

# %%
'd' + name1[1:]
# Out:
# 'dine'

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  keywords
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# ...

# %%
x = sqrt(23) #sqrt is inbuild function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(23)
#
# NameError: name 'sqrt' is not defined

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
import math #math is module

# %%
x = math.sqrt(25)

# %%
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(3.87))
# Out:
# 3

# %%
print(math.ceil(3.87))
# Out:
# 4

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
m.sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 m.sqrt(25)
#
# NameError: name 'm' is not defined

# %%
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pow
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
from math import sqrt, pow, floor, ceil

print(m.sqrt(10))
print(pow(4,5))
print(floor(3.2))
print(ceil(3.2))
# Out:
# 3.1622776601683795
# 1024.0
# 3
# 4

# %%
from math import *

print(m.sqrt(10))
print(pow(4,5))
print(floor(3.2))
print(ceil(3.2))
# Out:
# 3.1622776601683795
# 1024.0
# 3
# 4

# %%
round(pow(2,3))
# Out:
# 8

# %% [markdown]
#  input()

# %%
x = input()
x
# Out:
#  4
# '4'

# %%
x = input()
y = input()

z = x+y
print(z)
# Out:
#  4
#  4
# 44

# %%
type(y)
type(x)
# Out:
# str

# %%
type(x)
# Out:
# str

# %%
x1 = input('Enter the first number')
y1 = input('Enter the second number')
z1 = x1 + y1
print(z1)
# Out:
# Enter the first number 1
# Enter the second number 1
# 11

# %%
x1 = input('user name')
y1 = input('password')
z1 = x1+y1
print(z1)
# Out:
# user name nit
# password nit
# nitnit

# %%
x1 = input('Enter the first number:')
a1 = int(x1)
y1 = input('Enter the second number: ')
b1 = int(y1)
z1 = a1+b1
print(z1)
# Out:
# Enter the first number: 2
# Enter the second number:  2
# 4

# %%
x1 = int(input('Enter the first number'))
y1 = int(input('Enter the second number'))
z1 = x1+y1
print(z1)
# Out:
# Enter the first number 2
# Enter the second number 2
# 4

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[0])
# Out:
# h

# %%
print(st[0:2])
# Out:
# he

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string hello
# h

# %%
st = input('enter a string:')[5:7]
print(st)
# Out:
# enter a string: hello

# %%
st = input('enter as string')
print(st)
# Out:
# enter as string 2+6-3*2
# 2+6-3*2

# %%
result = input('Enter as tring:')
print(result)
# Out:
# Enter as tring: 2+6-3*2
# 2+6-3*2

# %%
result = int(input('Enter a string'))
print(result)
# Out:
# Enter a string 2+6-3*2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 result = int(input('Enter a string'))
#       2 print(result)
#
# ValueError: invalid literal for int() with base 10: '2+6-3*2'

# %% [markdown]
# eval()

# %%
result = eval(input('Enter an expression:'))
print(result)
# Out:
# Enter an expression: 2+2-3
# 1

# %%
values = input("Enter values:").split()
print(values)
# Out:
# Enter values: hellonareshit
# ['hellonareshit']
